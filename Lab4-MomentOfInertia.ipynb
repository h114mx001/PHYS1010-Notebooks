# %% [markdown]
# As we derive from the formula:

# %%
#ploting net torque vs. angular acceleration

data = [(1.313, 0.013), (1.643, 0.017), (1.966, 0.022), (2.300, 0.026), (2.593, 0.030), (2.945, 0.035)]
var('a, b, x')
model(x) = a * x + b
sol = find_fit(data,model)
show(sol)
f(x) = model(a=sol[0].rhs(),b=sol[1].rhs())
a = plot([])
a += plot(f(x),x,[1.3, 3.0])
a += list_plot(data,color='red')
show(a)
# Out:
# [a == 0.013487720745859244, b == -0.004850552787228257]
# Graphics object consisting of 2 graphics primitives
